# %%
import torch
import torch_geometric

from torch.nn import Linear
from torch.nn.functional import elu
from torch_geometric.nn.conv import SplineConv
from torch_geometric.nn.norm import BatchNorm
from torch_geometric.transforms import Cartesian


import torch

from torch_geometric.data import Data
from torch_geometric.nn.pool import max_pool_x, voxel_grid
from typing import List, Optional, Tuple, Union


class MaxPoolingX(torch.nn.Module):

    def __init__(self, voxel_size: List[int], size: int):
        super(MaxPoolingX, self).__init__()
        self.voxel_size = voxel_size
        self.size = size

    def forward(self, x: torch.Tensor, pos: torch.Tensor, batch: Optional[torch.Tensor] = None
                ) -> Union[Tuple[torch.Tensor, torch.Tensor, torch.LongTensor, torch.Tensor, torch.Tensor], Data]:
        cluster = voxel_grid(pos, batch=batch, size=self.voxel_size)
        x, _ = max_pool_x(cluster, x, batch, size=self.size)
        return x

    def __repr__(self):
        return f"{self.__class__.__name__}(voxel_size={self.voxel_size}, size={self.size})"

import torch

from torch_geometric.data import Data
from torch_geometric.nn.pool import max_pool, voxel_grid
from typing import Callable, List, Optional, Tuple, Union


class MaxPooling(torch.nn.Module):

    def __init__(self, size: List[int], transform: Callable[[Data, ], Data] = None):
        super(MaxPooling, self).__init__()
        self.voxel_size = list(size)
        self.transform = transform

    def forward(self, x: torch.Tensor, pos: torch.Tensor, batch: Optional[torch.Tensor] = None,
                edge_index: Optional[torch.Tensor] = None, return_data_obj: bool = False
                ) -> Union[Tuple[torch.Tensor, torch.Tensor, torch.LongTensor, torch.Tensor, torch.Tensor], Data]:
        assert edge_index is not None, "edge_index must not be None"

        cluster = voxel_grid(pos[:, :2], batch=batch, size=self.voxel_size)
        data = Data(x=x, pos=pos, edge_index=edge_index, batch=batch)
        data = max_pool(cluster, data=data, transform=self.transform)  # transform for new edge attributes
        if return_data_obj:
            return data
        else:
            return data.x, data.pos, getattr(data, "batch"), data.edge_index, data.edge_attr

    def __repr__(self):
        return f"{self.__class__.__name__}(voxel_size={self.voxel_size})"

class GraphRes_lightheavy(torch.nn.Module):

    def __init__(self):
        super(GraphRes_lightheavy, self).__init__()
        dim = 3

        bias = False
        root_weight = False
        pooling_size=(16/346, 12/260)

        # Set dataset specific hyper-parameters.
        kernel_size = 2
        n = [1, 8, 16, 16, 16, 32, 32, 32, 32]
        pooling_outputs = 32
        #kernel_size = 8
        #n = [1, 16, 32, 32, 32, 128, 128, 128]
        #pooling_outputs = 128

        self.conv1 = SplineConv(n[0], n[1], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm1 = BatchNorm(in_channels=n[1])
        self.conv2 = SplineConv(n[1], n[2], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm2 = BatchNorm(in_channels=n[2])

        self.conv3 = SplineConv(n[2], n[3], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm3 = BatchNorm(in_channels=n[3])
        self.conv4 = SplineConv(n[3], n[4], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm4 = BatchNorm(in_channels=n[4])

        self.conv5 = SplineConv(n[4], n[5], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm5 = BatchNorm(in_channels=n[5])
        self.pool5 = MaxPooling(pooling_size, transform=Cartesian(norm=True, cat=False))

        self.conv6 = SplineConv(n[5], n[6], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm6 = BatchNorm(in_channels=n[6])
        self.conv7 = SplineConv(n[6], n[7], dim=dim, kernel_size=kernel_size, bias=bias, root_weight=root_weight)
        self.norm7 = BatchNorm(in_channels=n[7])

        self.pool7 = MaxPoolingX(0.25, size=16)
        self.fc = Linear(pooling_outputs * 16, out_features=2, bias=bias)

    def forward(self, data: torch_geometric.data.Batch) -> torch.Tensor:
        data.x = elu(self.conv1(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm1(data.x)
        data.x = elu(self.conv2(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm2(data.x)

        x_sc = data.x.clone()
        data.x = elu(self.conv3(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm3(data.x)
        data.x = elu(self.conv4(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm4(data.x)
        data.x = data.x + x_sc

        data.x = elu(self.conv5(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm5(data.x)
        data = self.pool5(data.x, pos=data.pos, batch=data.batch, edge_index=data.edge_index, return_data_obj=True)

        x_sc = data.x.clone()
        data.x = elu(self.conv6(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm6(data.x)
        data.x = elu(self.conv7(data.x, data.edge_index, data.edge_attr))
        data.x = self.norm7(data.x)
        data.x = data.x + x_sc

        x = self.pool7(data.x, pos=data.pos[:, :2], batch=data.batch)
        x = x.view(-1, self.fc.in_features)
        return self.fc(x)

model = GraphRes_lightheavy().cuda()

# %%
torch.load('/home/hussain/Downloads/model.pt')
# Out:
# GraphRes_lightheavy(
#   (conv1): SplineConv(1, 8, dim=3)
#   (norm1): BatchNorm(8)
#   (conv2): SplineConv(8, 16, dim=3)
#   (norm2): BatchNorm(16)
#   (conv3): SplineConv(16, 16, dim=3)
#   (norm3): BatchNorm(16)
#   (conv4): SplineConv(16, 16, dim=3)
#   (norm4): BatchNorm(16)
#   (conv5): SplineConv(16, 32, dim=3)
#   (norm5): BatchNorm(32)
#   (pool5): MaxPooling(voxel_size=[0.046242774566473986, 0.046153846153846156])
#   (conv6): SplineConv(32, 32, dim=3)
#   (norm6): BatchNorm(32)
#   (conv7): SplineConv(32, 32, dim=3)
#   (norm7): BatchNorm(32)
#   (pool7): MaxPoolingX(voxel_size=0.25, size=16)
#   (fc): Linear(in_features=512, out_features=2, bias=False)
# )

# %%
import json
with open('data/extractions/contact_extraction2/extraction_params.json', 'w') as f:
    params = json.dump({}, f)

# %%
from src.imports.TrainModel import TrainModel
# !rm -rf data/extractions/contact_extraction2/{test,train,val}/processed/*.pt

tm = TrainModel('data/extractions/contact_extraction2/', model.cuda(), batch=4, features='pol')
# Out:
# Processing...
# {'kNN': 32, 'node_features': 'pol'}
# Done!
# Processing...
# {'kNN': 32, 'node_features': 'pol'}
# Done!
# Processing...
# {'kNN': 32, 'node_features': 'pol'}
# Done!

# %%
tm.validate()
# Out:
# (2.6035049446375975, 6.5740485191345215)

# %%
for i in tm.val_loader:
    print(i)
# Out:
# DataBatch(x=[2851, 4], edge_index=[2, 44938], y=[1, 2], pos=[2851, 3], edge_attr=[44938, 3], batch=[2851], ptr=[2])
# DataBatch(x=[3227, 4], edge_index=[2, 51127], y=[1, 2], pos=[3227, 3], edge_attr=[51127, 3], batch=[3227], ptr=[2])
# DataBatch(x=[6523, 4], edge_index=[2, 104087], y=[1, 2], pos=[6523, 3], edge_attr=[104087, 3], batch=[6523], ptr=[2])
# DataBatch(x=[9330, 4], edge_index=[2, 149280], y=[1, 2], pos=[9330, 3], edge_attr=[149280, 3], batch=[9330], ptr=[2])
# DataBatch(x=[6930, 4], edge_index=[2, 110725], y=[1, 2], pos=[6930, 3], edge_attr=[110725, 3], batch=[6930], ptr=[2])
# DataBatch(x=[7467, 4], edge_index=[2, 119373], y=[1, 2], pos=[7467, 3], edge_attr=[119373, 3], batch=[7467], ptr=[2])
# DataBatch(x=[3565, 4], edge_index=[2, 56503], y=[1, 2], pos=[3565, 3], edge_attr=[56503, 3], batch=[3565], ptr=[2])
# DataBatch(x=[5554, 4], edge_index=[2, 88549], y=[1, 2], pos=[5554, 3], edge_attr=[88549, 3], batch=[5554], ptr=[2])
# DataBatch(x=[7403, 4], edge_index=[2, 118427], y=[1, 2], pos=[7403, 3], edge_attr=[118427, 3], batch=[7403], ptr=[2])
# DataBatch(x=[2599, 4], edge_index=[2, 41175], y=[1, 2], pos=[2599, 3], edge_attr=[41175, 3], batch=[2599], ptr=[2])
# DataBatch(x=[3948, 4], edge_index=[2, 62899], y=[1, 2], pos=[3948, 3], edge_attr=[62899, 3], batch=[3948], ptr=[2])
# DataBatch(x=[4991, 4], edge_index=[2, 79577], y=[1, 2], pos=[4991, 3], edge_attr=[79577, 3], batch=[4991], ptr=[2])
# DataBatch(x=[7925, 4], edge_index=[2, 126696], y=[1, 2], pos=[7925, 3], edge_attr=[126696, 3], batch=[7925], ptr=[2])
# DataBatch(x=[5353, 4], edge_index=[2, 85284], y=[1, 2], pos=[5353, 3], edge_attr=[85284, 3], batch=[5353], ptr=[2])
# DataBatch(x=[6274, 4], edge_index=[2, 100147], y=[1, 2], pos=[6274, 3], edge_attr=[100147, 3], batch=[6274], ptr=[2])
# DataBatch(x=[5569, 4], edge_index=[2, 88769], y=[1, 2], pos=[5569, 3], edge_attr=[88769, 3], batch=[5569], ptr=[2])
# DataBatch(x=[5426, 4], edge_index=[2, 86495], y=[1, 2], pos=[5426, 3], edge_attr=[86495, 3], batch=[5426], ptr=[2])
# DataBatch(x=[7685, 4], edge_index=[2, 122876], y=[1, 2], pos=[7685, 3], edge_attr=[122876, 3], batch=[7685], ptr=[2])
# DataBatch(x=[6200, 4], edge_index=[2, 98888], y=[1, 2], pos=[6200, 3], edge_attr=[98888, 3], batch=[6200], ptr=[2])
# DataBatch(x=[7589, 4], edge_index=[2, 121389], y=[1, 2], pos=[7589, 3], edge_attr=[121389, 3], batch=[7589], ptr=[2])
# DataBatch(x=[6328, 4], edge_index=[2, 100926], y=[1, 2], pos=[6328, 3], edge_attr=[100926, 3], batch=[6328], ptr=[2])
# DataBatch(x=[3523, 4], edge_index=[2, 55767], y=[1, 2], pos=[3523, 3], edge_attr=[55767, 3], batch=[3523], ptr=[2])
# DataBatch(x=[1319, 4], edge_index=[2, 20609], y=[1, 2], pos=[1319, 3], edge_attr=[20609, 3], batch=[1319], ptr=[2])
# DataBatch(x=[4891, 4], edge_index=[2, 77978], y=[1, 2], pos=[4891, 3], edge_attr=[77978, 3], batch=[4891], ptr=[2])
# DataBatch(x=[4608, 4], edge_index=[2, 73281], y=[1, 2], pos=[4608, 3], edge_attr=[73281, 3], batch=[4608], ptr=[2])
# DataBatch(x=[2759, 4], edge_index=[2, 43687], y=[1, 2], pos=[2759, 3], edge_attr=[43687, 3], batch=[2759], ptr=[2])
# DataBatch(x=[3134, 4], edge_index=[2, 49799], y=[1, 2], pos=[3134, 3], edge_attr=[49799, 3], batch=[3134], ptr=[2])
# DataBatch(x=[3201, 4], edge_index=[2, 50757], y=[1, 2], pos=[3201, 3], edge_attr=[50757, 3], batch=[3201], ptr=[2])
# DataBatch(x=[5059, 4], edge_index=[2, 80514], y=[1, 2], pos=[5059, 3], edge_attr=[80514, 3], batch=[5059], ptr=[2])
# DataBatch(x=[3280, 4], edge_index=[2, 51953], y=[1, 2], pos=[3280, 3], edge_attr=[51953, 3], batch=[3280], ptr=[2])
# DataBatch(x=[1724, 4], edge_index=[2, 26727], y=[1, 2], pos=[1724, 3], edge_attr=[26727, 3], batch=[1724], ptr=[2])
# DataBatch(x=[4406, 4], edge_index=[2, 70009], y=[1, 2], pos=[4406, 3], edge_attr=[70009, 3], batch=[4406], ptr=[2])
# DataBatch(x=[2089, 4], edge_index=[2, 32798], y=[1, 2], pos=[2089, 3], edge_attr=[32798, 3], batch=[2089], ptr=[2])
# DataBatch(x=[2309, 4], edge_index=[2, 36639], y=[1, 2], pos=[2309, 3], edge_attr=[36639, 3], batch=[2309], ptr=[2])
# DataBatch(x=[7811, 4], edge_index=[2, 124952], y=[1, 2], pos=[7811, 3], edge_attr=[124952, 3], batch=[7811], ptr=[2])
# DataBatch(x=[7449, 4], edge_index=[2, 119131], y=[1, 2], pos=[7449, 3], edge_attr=[119131, 3], batch=[7449], ptr=[2])
# DataBatch(x=[2965, 4], edge_index=[2, 46887], y=[1, 2], pos=[2965, 3], edge_attr=[46887, 3], batch=[2965], ptr=[2])
# DataBatch(x=[4792, 4], edge_index=[2, 76278], y=[1, 2], pos=[4792, 3], edge_attr=[76278, 3], batch=[4792], ptr=[2])
# DataBatch(x=[8718, 4], edge_index=[2, 139372], y=[1, 2], pos=[8718, 3], edge_attr=[139372, 3], batch=[8718], ptr=[2])
# DataBatch(x=[4334, 4], edge_index=[2, 68830], y=[1, 2], pos=[4334, 3], edge_attr=[68830, 3], batch=[4334], ptr=[2])
# DataBatch(x=[2528, 4], edge_index=[2, 40098], y=[1, 2], pos=[2528, 3], edge_attr=[40098, 3], batch=[2528], ptr=[2])
# DataBatch(x=[4598, 4], edge_index=[2, 73183], y=[1, 2], pos=[4598, 3], edge_attr=[73183, 3], batch=[4598], ptr=[2])
# DataBatch(x=[3993, 4], edge_index=[2, 63389], y=[1, 2], pos=[3993, 3], edge_attr=[63389, 3], batch=[3993], ptr=[2])
# DataBatch(x=[2817, 4], edge_index=[2, 44770], y=[1, 2], pos=[2817, 3], edge_attr=[44770, 3], batch=[2817], ptr=[2])
# DataBatch(x=[6788, 4], edge_index=[2, 108409], y=[1, 2], pos=[6788, 3], edge_attr=[108409, 3], batch=[6788], ptr=[2])
# DataBatch(x=[2089, 4], edge_index=[2, 33123], y=[1, 2], pos=[2089, 3], edge_attr=[33123, 3], batch=[2089], ptr=[2])
# DataBatch(x=[2546, 4], edge_index=[2, 40154], y=[1, 2], pos=[2546, 3], edge_attr=[40154, 3], batch=[2546], ptr=[2])
# DataBatch(x=[3235, 4], edge_index=[2, 51383], y=[1, 2], pos=[3235, 3], edge_attr=[51383, 3], batch=[3235], ptr=[2])
# DataBatch(x=[992, 4], edge_index=[2, 15338], y=[1, 2], pos=[992, 3], edge_attr=[15338, 3], batch=[992], ptr=[2])
# DataBatch(x=[8339, 4], edge_index=[2, 133376], y=[1, 2], pos=[8339, 3], edge_attr=[133376, 3], batch=[8339], ptr=[2])
# DataBatch(x=[5423, 4], edge_index=[2, 86389], y=[1, 2], pos=[5423, 3], edge_attr=[86389, 3], batch=[5423], ptr=[2])
# DataBatch(x=[7058, 4], edge_index=[2, 112781], y=[1, 2], pos=[7058, 3], edge_attr=[112781, 3], batch=[7058], ptr=[2])
# DataBatch(x=[5396, 4], edge_index=[2, 85970], y=[1, 2], pos=[5396, 3], edge_attr=[85970, 3], batch=[5396], ptr=[2])
# DataBatch(x=[4631, 4], edge_index=[2, 73596], y=[1, 2], pos=[4631, 3], edge_attr=[73596, 3], batch=[4631], ptr=[2])
# DataBatch(x=[6099, 4], edge_index=[2, 97458], y=[1, 2], pos=[6099, 3], edge_attr=[97458, 3], batch=[6099], ptr=[2])
# DataBatch(x=[2193, 4], edge_index=[2, 34513], y=[1, 2], pos=[2193, 3], edge_attr=[34513, 3], batch=[2193], ptr=[2])
# DataBatch(x=[3764, 4], edge_index=[2, 59397], y=[1, 2], pos=[3764, 3], edge_attr=[59397, 3], batch=[3764], ptr=[2])
# DataBatch(x=[8104, 4], edge_index=[2, 129566], y=[1, 2], pos=[8104, 3], edge_attr=[129566, 3], batch=[8104], ptr=[2])
# DataBatch(x=[5204, 4], edge_index=[2, 82843], y=[1, 2], pos=[5204, 3], edge_attr=[82843, 3], batch=[5204], ptr=[2])
# DataBatch(x=[6261, 4], edge_index=[2, 99926], y=[1, 2], pos=[6261, 3], edge_attr=[99926, 3], batch=[6261], ptr=[2])
# DataBatch(x=[5155, 4], edge_index=[2, 82140], y=[1, 2], pos=[5155, 3], edge_attr=[82140, 3], batch=[5155], ptr=[2])
# DataBatch(x=[2764, 4], edge_index=[2, 43374], y=[1, 2], pos=[2764, 3], edge_attr=[43374, 3], batch=[2764], ptr=[2])
# DataBatch(x=[2803, 4], edge_index=[2, 44292], y=[1, 2], pos=[2803, 3], edge_attr=[44292, 3], batch=[2803], ptr=[2])
# DataBatch(x=[3151, 4], edge_index=[2, 49575], y=[1, 2], pos=[3151, 3], edge_attr=[49575, 3], batch=[3151], ptr=[2])
# DataBatch(x=[3492, 4], edge_index=[2, 55397], y=[1, 2], pos=[3492, 3], edge_attr=[55397, 3], batch=[3492], ptr=[2])
# DataBatch(x=[4040, 4], edge_index=[2, 63933], y=[1, 2], pos=[4040, 3], edge_attr=[63933, 3], batch=[4040], ptr=[2])
# DataBatch(x=[5493, 4], edge_index=[2, 87512], y=[1, 2], pos=[5493, 3], edge_attr=[87512, 3], batch=[5493], ptr=[2])
# DataBatch(x=[4072, 4], edge_index=[2, 64462], y=[1, 2], pos=[4072, 3], edge_attr=[64462, 3], batch=[4072], ptr=[2])
# DataBatch(x=[4977, 4], edge_index=[2, 79252], y=[1, 2], pos=[4977, 3], edge_attr=[79252, 3], batch=[4977], ptr=[2])
# DataBatch(x=[7049, 4], edge_index=[2, 112700], y=[1, 2], pos=[7049, 3], edge_attr=[112700, 3], batch=[7049], ptr=[2])
# DataBatch(x=[5838, 4], edge_index=[2, 93097], y=[1, 2], pos=[5838, 3], edge_attr=[93097, 3], batch=[5838], ptr=[2])
# DataBatch(x=[3653, 4], edge_index=[2, 58040], y=[1, 2], pos=[3653, 3], edge_attr=[58040, 3], batch=[3653], ptr=[2])
# DataBatch(x=[3147, 4], edge_index=[2, 49896], y=[1, 2], pos=[3147, 3], edge_attr=[49896, 3], batch=[3147], ptr=[2])
# DataBatch(x=[3498, 4], edge_index=[2, 55507], y=[1, 2], pos=[3498, 3], edge_attr=[55507, 3], batch=[3498], ptr=[2])
# DataBatch(x=[865, 4], edge_index=[2, 13195], y=[1, 2], pos=[865, 3], edge_attr=[13195, 3], batch=[865], ptr=[2])
# DataBatch(x=[4852, 4], edge_index=[2, 77074], y=[1, 2], pos=[4852, 3], edge_attr=[77074, 3], batch=[4852], ptr=[2])
# DataBatch(x=[5009, 4], edge_index=[2, 79606], y=[1, 2], pos=[5009, 3], edge_attr=[79606, 3], batch=[5009], ptr=[2])
# DataBatch(x=[3514, 4], edge_index=[2, 55453], y=[1, 2], pos=[3514, 3], edge_attr=[55453, 3], batch=[3514], ptr=[2])
# DataBatch(x=[4860, 4], edge_index=[2, 77367], y=[1, 2], pos=[4860, 3], edge_attr=[77367, 3], batch=[4860], ptr=[2])
# DataBatch(x=[6837, 4], edge_index=[2, 109207], y=[1, 2], pos=[6837, 3], edge_attr=[109207, 3], batch=[6837], ptr=[2])
# DataBatch(x=[5993, 4], edge_index=[2, 95593], y=[1, 2], pos=[5993, 3], edge_attr=[95593, 3], batch=[5993], ptr=[2])
# DataBatch(x=[8937, 4], edge_index=[2, 142968], y=[1, 2], pos=[8937, 3], edge_attr=[142968, 3], batch=[8937], ptr=[2])
# DataBatch(x=[5127, 4], edge_index=[2, 81874], y=[1, 2], pos=[5127, 3], edge_attr=[81874, 3], batch=[5127], ptr=[2])
# DataBatch(x=[3886, 4], edge_index=[2, 61852], y=[1, 2], pos=[3886, 3], edge_attr=[61852, 3], batch=[3886], ptr=[2])
# DataBatch(x=[5028, 4], edge_index=[2, 79968], y=[1, 2], pos=[5028, 3], edge_attr=[79968, 3], batch=[5028], ptr=[2])
# DataBatch(x=[2230, 4], edge_index=[2, 35080], y=[1, 2], pos=[2230, 3], edge_attr=[35080, 3], batch=[2230], ptr=[2])
# DataBatch(x=[6564, 4], edge_index=[2, 104814], y=[1, 2], pos=[6564, 3], edge_attr=[104814, 3], batch=[6564], ptr=[2])
# DataBatch(x=[5667, 4], edge_index=[2, 90407], y=[1, 2], pos=[5667, 3], edge_attr=[90407, 3], batch=[5667], ptr=[2])
# DataBatch(x=[1898, 4], edge_index=[2, 29979], y=[1, 2], pos=[1898, 3], edge_attr=[29979, 3], batch=[1898], ptr=[2])
# DataBatch(x=[1864, 4], edge_index=[2, 29343], y=[1, 2], pos=[1864, 3], edge_attr=[29343, 3], batch=[1864], ptr=[2])
# DataBatch(x=[2486, 4], edge_index=[2, 38908], y=[1, 2], pos=[2486, 3], edge_attr=[38908, 3], batch=[2486], ptr=[2])
# DataBatch(x=[2808, 4], edge_index=[2, 43989], y=[1, 2], pos=[2808, 3], edge_attr=[43989, 3], batch=[2808], ptr=[2])
# DataBatch(x=[2511, 4], edge_index=[2, 39689], y=[1, 2], pos=[2511, 3], edge_attr=[39689, 3], batch=[2511], ptr=[2])
# DataBatch(x=[3681, 4], edge_index=[2, 58430], y=[1, 2], pos=[3681, 3], edge_attr=[58430, 3], batch=[3681], ptr=[2])
# DataBatch(x=[2904, 4], edge_index=[2, 45851], y=[1, 2], pos=[2904, 3], edge_attr=[45851, 3], batch=[2904], ptr=[2])
# DataBatch(x=[4859, 4], edge_index=[2, 77294], y=[1, 2], pos=[4859, 3], edge_attr=[77294, 3], batch=[4859], ptr=[2])
# DataBatch(x=[697, 4], edge_index=[2, 10554], y=[1, 2], pos=[697, 3], edge_attr=[10554, 3], batch=[697], ptr=[2])
# DataBatch(x=[6014, 4], edge_index=[2, 95978], y=[1, 2], pos=[6014, 3], edge_attr=[95978, 3], batch=[6014], ptr=[2])
# DataBatch(x=[4696, 4], edge_index=[2, 74731], y=[1, 2], pos=[4696, 3], edge_attr=[74731, 3], batch=[4696], ptr=[2])
# DataBatch(x=[8474, 4], edge_index=[2, 135554], y=[1, 2], pos=[8474, 3], edge_attr=[135554, 3], batch=[8474], ptr=[2])
# DataBatch(x=[8817, 4], edge_index=[2, 141053], y=[1, 2], pos=[8817, 3], edge_attr=[141053, 3], batch=[8817], ptr=[2])
# DataBatch(x=[7633, 4], edge_index=[2, 122031], y=[1, 2], pos=[7633, 3], edge_attr=[122031, 3], batch=[7633], ptr=[2])
# DataBatch(x=[6502, 4], edge_index=[2, 103825], y=[1, 2], pos=[6502, 3], edge_attr=[103825, 3], batch=[6502], ptr=[2])
# DataBatch(x=[5818, 4], edge_index=[2, 92949], y=[1, 2], pos=[5818, 3], edge_attr=[92949, 3], batch=[5818], ptr=[2])
# DataBatch(x=[2897, 4], edge_index=[2, 45959], y=[1, 2], pos=[2897, 3], edge_attr=[45959, 3], batch=[2897], ptr=[2])
# DataBatch(x=[7403, 4], edge_index=[2, 118376], y=[1, 2], pos=[7403, 3], edge_attr=[118376, 3], batch=[7403], ptr=[2])
# DataBatch(x=[5047, 4], edge_index=[2, 80240], y=[1, 2], pos=[5047, 3], edge_attr=[80240, 3], batch=[5047], ptr=[2])
# DataBatch(x=[2996, 4], edge_index=[2, 47510], y=[1, 2], pos=[2996, 3], edge_attr=[47510, 3], batch=[2996], ptr=[2])
# DataBatch(x=[8405, 4], edge_index=[2, 134372], y=[1, 2], pos=[8405, 3], edge_attr=[134372, 3], batch=[8405], ptr=[2])
# DataBatch(x=[7185, 4], edge_index=[2, 114871], y=[1, 2], pos=[7185, 3], edge_attr=[114871, 3], batch=[7185], ptr=[2])
# DataBatch(x=[798, 4], edge_index=[2, 11462], y=[1, 2], pos=[798, 3], edge_attr=[11462, 3], batch=[798], ptr=[2])
# DataBatch(x=[5262, 4], edge_index=[2, 83917], y=[1, 2], pos=[5262, 3], edge_attr=[83917, 3], batch=[5262], ptr=[2])
# DataBatch(x=[7302, 4], edge_index=[2, 116650], y=[1, 2], pos=[7302, 3], edge_attr=[116650, 3], batch=[7302], ptr=[2])
# DataBatch(x=[4704, 4], edge_index=[2, 74821], y=[1, 2], pos=[4704, 3], edge_attr=[74821, 3], batch=[4704], ptr=[2])
# DataBatch(x=[1100, 4], edge_index=[2, 16955], y=[1, 2], pos=[1100, 3], edge_attr=[16955, 3], batch=[1100], ptr=[2])
# DataBatch(x=[7330, 4], edge_index=[2, 116985], y=[1, 2], pos=[7330, 3], edge_attr=[116985, 3], batch=[7330], ptr=[2])
# DataBatch(x=[3843, 4], edge_index=[2, 60978], y=[1, 2], pos=[3843, 3], edge_attr=[60978, 3], batch=[3843], ptr=[2])
# DataBatch(x=[5905, 4], edge_index=[2, 94157], y=[1, 2], pos=[5905, 3], edge_attr=[94157, 3], batch=[5905], ptr=[2])
# DataBatch(x=[2191, 4], edge_index=[2, 34477], y=[1, 2], pos=[2191, 3], edge_attr=[34477, 3], batch=[2191], ptr=[2])
# DataBatch(x=[6749, 4], edge_index=[2, 107708], y=[1, 2], pos=[6749, 3], edge_attr=[107708, 3], batch=[6749], ptr=[2])
# DataBatch(x=[5117, 4], edge_index=[2, 81492], y=[1, 2], pos=[5117, 3], edge_attr=[81492, 3], batch=[5117], ptr=[2])
# DataBatch(x=[1941, 4], edge_index=[2, 30469], y=[1, 2], pos=[1941, 3], edge_attr=[30469, 3], batch=[1941], ptr=[2])
# DataBatch(x=[7012, 4], edge_index=[2, 112129], y=[1, 2], pos=[7012, 3], edge_attr=[112129, 3], batch=[7012], ptr=[2])
# DataBatch(x=[3753, 4], edge_index=[2, 59527], y=[1, 2], pos=[3753, 3], edge_attr=[59527, 3], batch=[3753], ptr=[2])
# DataBatch(x=[687, 4], edge_index=[2, 10402], y=[1, 2], pos=[687, 3], edge_attr=[10402, 3], batch=[687], ptr=[2])
# DataBatch(x=[4657, 4], edge_index=[2, 74135], y=[1, 2], pos=[4657, 3], edge_attr=[74135, 3], batch=[4657], ptr=[2])
# DataBatch(x=[1896, 4], edge_index=[2, 29604], y=[1, 2], pos=[1896, 3], edge_attr=[29604, 3], batch=[1896], ptr=[2])
# DataBatch(x=[8989, 4], edge_index=[2, 143811], y=[1, 2], pos=[8989, 3], edge_attr=[143811, 3], batch=[8989], ptr=[2])
# DataBatch(x=[7087, 4], edge_index=[2, 113242], y=[1, 2], pos=[7087, 3], edge_attr=[113242, 3], batch=[7087], ptr=[2])
# DataBatch(x=[3694, 4], edge_index=[2, 58664], y=[1, 2], pos=[3694, 3], edge_attr=[58664, 3], batch=[3694], ptr=[2])
# DataBatch(x=[4793, 4], edge_index=[2, 76365], y=[1, 2], pos=[4793, 3], edge_attr=[76365, 3], batch=[4793], ptr=[2])
# DataBatch(x=[4925, 4], edge_index=[2, 78310], y=[1, 2], pos=[4925, 3], edge_attr=[78310, 3], batch=[4925], ptr=[2])
# DataBatch(x=[6624, 4], edge_index=[2, 105751], y=[1, 2], pos=[6624, 3], edge_attr=[105751, 3], batch=[6624], ptr=[2])
# DataBatch(x=[4749, 4], edge_index=[2, 75648], y=[1, 2], pos=[4749, 3], edge_attr=[75648, 3], batch=[4749], ptr=[2])
# DataBatch(x=[6828, 4], edge_index=[2, 108954], y=[1, 2], pos=[6828, 3], edge_attr=[108954, 3], batch=[6828], ptr=[2])
# DataBatch(x=[811, 4], edge_index=[2, 12165], y=[1, 2], pos=[811, 3], edge_attr=[12165, 3], batch=[811], ptr=[2])
# DataBatch(x=[5702, 4], edge_index=[2, 91081], y=[1, 2], pos=[5702, 3], edge_attr=[91081, 3], batch=[5702], ptr=[2])
# DataBatch(x=[6310, 4], edge_index=[2, 100691], y=[1, 2], pos=[6310, 3], edge_attr=[100691, 3], batch=[6310], ptr=[2])
# DataBatch(x=[1987, 4], edge_index=[2, 31178], y=[1, 2], pos=[1987, 3], edge_attr=[31178, 3], batch=[1987], ptr=[2])
# DataBatch(x=[5674, 4], edge_index=[2, 90456], y=[1, 2], pos=[5674, 3], edge_attr=[90456, 3], batch=[5674], ptr=[2])
# DataBatch(x=[6767, 4], edge_index=[2, 107987], y=[1, 2], pos=[6767, 3], edge_attr=[107987, 3], batch=[6767], ptr=[2])
# DataBatch(x=[5152, 4], edge_index=[2, 82133], y=[1, 2], pos=[5152, 3], edge_attr=[82133, 3], batch=[5152], ptr=[2])
# DataBatch(x=[2981, 4], edge_index=[2, 46712], y=[1, 2], pos=[2981, 3], edge_attr=[46712, 3], batch=[2981], ptr=[2])
# DataBatch(x=[10088, 4], edge_index=[2, 161386], y=[1, 2], pos=[10088, 3], edge_attr=[161386, 3], batch=[10088], ptr=[2])
# DataBatch(x=[6781, 4], edge_index=[2, 108455], y=[1, 2], pos=[6781, 3], edge_attr=[108455, 3], batch=[6781], ptr=[2])
# DataBatch(x=[4821, 4], edge_index=[2, 76742], y=[1, 2], pos=[4821, 3], edge_attr=[76742, 3], batch=[4821], ptr=[2])
# DataBatch(x=[6010, 4], edge_index=[2, 95872], y=[1, 2], pos=[6010, 3], edge_attr=[95872, 3], batch=[6010], ptr=[2])
# DataBatch(x=[3290, 4], edge_index=[2, 52131], y=[1, 2], pos=[3290, 3], edge_attr=[52131, 3], batch=[3290], ptr=[2])
# DataBatch(x=[8683, 4], edge_index=[2, 138837], y=[1, 2], pos=[8683, 3], edge_attr=[138837, 3], batch=[8683], ptr=[2])
# DataBatch(x=[1824, 4], edge_index=[2, 28610], y=[1, 2], pos=[1824, 3], edge_attr=[28610, 3], batch=[1824], ptr=[2])
# DataBatch(x=[4331, 4], edge_index=[2, 68836], y=[1, 2], pos=[4331, 3], edge_attr=[68836, 3], batch=[4331], ptr=[2])
# DataBatch(x=[7249, 4], edge_index=[2, 115718], y=[1, 2], pos=[7249, 3], edge_attr=[115718, 3], batch=[7249], ptr=[2])
# DataBatch(x=[1361, 4], edge_index=[2, 21112], y=[1, 2], pos=[1361, 3], edge_attr=[21112, 3], batch=[1361], ptr=[2])
# DataBatch(x=[4300, 4], edge_index=[2, 68450], y=[1, 2], pos=[4300, 3], edge_attr=[68450, 3], batch=[4300], ptr=[2])
# DataBatch(x=[5049, 4], edge_index=[2, 80417], y=[1, 2], pos=[5049, 3], edge_attr=[80417, 3], batch=[5049], ptr=[2])
# DataBatch(x=[7466, 4], edge_index=[2, 119235], y=[1, 2], pos=[7466, 3], edge_attr=[119235, 3], batch=[7466], ptr=[2])
# DataBatch(x=[7297, 4], edge_index=[2, 116539], y=[1, 2], pos=[7297, 3], edge_attr=[116539, 3], batch=[7297], ptr=[2])
# DataBatch(x=[6000, 4], edge_index=[2, 95728], y=[1, 2], pos=[6000, 3], edge_attr=[95728, 3], batch=[6000], ptr=[2])
# DataBatch(x=[3879, 4], edge_index=[2, 61581], y=[1, 2], pos=[3879, 3], edge_attr=[61581, 3], batch=[3879], ptr=[2])
# DataBatch(x=[7945, 4], edge_index=[2, 127036], y=[1, 2], pos=[7945, 3], edge_attr=[127036, 3], batch=[7945], ptr=[2])
# DataBatch(x=[4692, 4], edge_index=[2, 74537], y=[1, 2], pos=[4692, 3], edge_attr=[74537, 3], batch=[4692], ptr=[2])
# DataBatch(x=[4547, 4], edge_index=[2, 72446], y=[1, 2], pos=[4547, 3], edge_attr=[72446, 3], batch=[4547], ptr=[2])
# DataBatch(x=[8141, 4], edge_index=[2, 130228], y=[1, 2], pos=[8141, 3], edge_attr=[130228, 3], batch=[8141], ptr=[2])
# DataBatch(x=[3049, 4], edge_index=[2, 48203], y=[1, 2], pos=[3049, 3], edge_attr=[48203, 3], batch=[3049], ptr=[2])
# DataBatch(x=[2285, 4], edge_index=[2, 35531], y=[1, 2], pos=[2285, 3], edge_attr=[35531, 3], batch=[2285], ptr=[2])
# DataBatch(x=[697, 4], edge_index=[2, 10506], y=[1, 2], pos=[697, 3], edge_attr=[10506, 3], batch=[697], ptr=[2])
# DataBatch(x=[1884, 4], edge_index=[2, 29603], y=[1, 2], pos=[1884, 3], edge_attr=[29603, 3], batch=[1884], ptr=[2])
# DataBatch(x=[1386, 4], edge_index=[2, 21570], y=[1, 2], pos=[1386, 3], edge_attr=[21570, 3], batch=[1386], ptr=[2])
# DataBatch(x=[1394, 4], edge_index=[2, 21840], y=[1, 2], pos=[1394, 3], edge_attr=[21840, 3], batch=[1394], ptr=[2])
# DataBatch(x=[5647, 4], edge_index=[2, 90208], y=[1, 2], pos=[5647, 3], edge_attr=[90208, 3], batch=[5647], ptr=[2])
# DataBatch(x=[1079, 4], edge_index=[2, 16289], y=[1, 2], pos=[1079, 3], edge_attr=[16289, 3], batch=[1079], ptr=[2])
# DataBatch(x=[4366, 4], edge_index=[2, 69590], y=[1, 2], pos=[4366, 3], edge_attr=[69590, 3], batch=[4366], ptr=[2])
# DataBatch(x=[9021, 4], edge_index=[2, 144318], y=[1, 2], pos=[9021, 3], edge_attr=[144318, 3], batch=[9021], ptr=[2])
# DataBatch(x=[3787, 4], edge_index=[2, 60101], y=[1, 2], pos=[3787, 3], edge_attr=[60101, 3], batch=[3787], ptr=[2])
# DataBatch(x=[3927, 4], edge_index=[2, 62329], y=[1, 2], pos=[3927, 3], edge_attr=[62329, 3], batch=[3927], ptr=[2])
# DataBatch(x=[5361, 4], edge_index=[2, 85361], y=[1, 2], pos=[5361, 3], edge_attr=[85361, 3], batch=[5361], ptr=[2])
# DataBatch(x=[7807, 4], edge_index=[2, 124828], y=[1, 2], pos=[7807, 3], edge_attr=[124828, 3], batch=[7807], ptr=[2])
# DataBatch(x=[8165, 4], edge_index=[2, 130627], y=[1, 2], pos=[8165, 3], edge_attr=[130627, 3], batch=[8165], ptr=[2])
# DataBatch(x=[5403, 4], edge_index=[2, 86023], y=[1, 2], pos=[5403, 3], edge_attr=[86023, 3], batch=[5403], ptr=[2])
# DataBatch(x=[1023, 4], edge_index=[2, 14921], y=[1, 2], pos=[1023, 3], edge_attr=[14921, 3], batch=[1023], ptr=[2])
# DataBatch(x=[3954, 4], edge_index=[2, 62804], y=[1, 2], pos=[3954, 3], edge_attr=[62804, 3], batch=[3954], ptr=[2])
# DataBatch(x=[4998, 4], edge_index=[2, 79638], y=[1, 2], pos=[4998, 3], edge_attr=[79638, 3], batch=[4998], ptr=[2])
# DataBatch(x=[2962, 4], edge_index=[2, 46782], y=[1, 2], pos=[2962, 3], edge_attr=[46782, 3], batch=[2962], ptr=[2])
# DataBatch(x=[6230, 4], edge_index=[2, 99494], y=[1, 2], pos=[6230, 3], edge_attr=[99494, 3], batch=[6230], ptr=[2])
# DataBatch(x=[5995, 4], edge_index=[2, 95580], y=[1, 2], pos=[5995, 3], edge_attr=[95580, 3], batch=[5995], ptr=[2])
# DataBatch(x=[3907, 4], edge_index=[2, 62075], y=[1, 2], pos=[3907, 3], edge_attr=[62075, 3], batch=[3907], ptr=[2])
# DataBatch(x=[3325, 4], edge_index=[2, 52350], y=[1, 2], pos=[3325, 3], edge_attr=[52350, 3], batch=[3325], ptr=[2])
# DataBatch(x=[3421, 4], edge_index=[2, 54278], y=[1, 2], pos=[3421, 3], edge_attr=[54278, 3], batch=[3421], ptr=[2])
# DataBatch(x=[8052, 4], edge_index=[2, 128826], y=[1, 2], pos=[8052, 3], edge_attr=[128826, 3], batch=[8052], ptr=[2])
# DataBatch(x=[7572, 4], edge_index=[2, 120979], y=[1, 2], pos=[7572, 3], edge_attr=[120979, 3], batch=[7572], ptr=[2])
# DataBatch(x=[4164, 4], edge_index=[2, 66287], y=[1, 2], pos=[4164, 3], edge_attr=[66287, 3], batch=[4164], ptr=[2])
# DataBatch(x=[7039, 4], edge_index=[2, 112348], y=[1, 2], pos=[7039, 3], edge_attr=[112348, 3], batch=[7039], ptr=[2])
# DataBatch(x=[6745, 4], edge_index=[2, 107650], y=[1, 2], pos=[6745, 3], edge_attr=[107650, 3], batch=[6745], ptr=[2])
# DataBatch(x=[7662, 4], edge_index=[2, 122475], y=[1, 2], pos=[7662, 3], edge_attr=[122475, 3], batch=[7662], ptr=[2])
# DataBatch(x=[6109, 4], edge_index=[2, 97568], y=[1, 2], pos=[6109, 3], edge_attr=[97568, 3], batch=[6109], ptr=[2])
# DataBatch(x=[8973, 4], edge_index=[2, 143560], y=[1, 2], pos=[8973, 3], edge_attr=[143560, 3], batch=[8973], ptr=[2])
# DataBatch(x=[6345, 4], edge_index=[2, 101184], y=[1, 2], pos=[6345, 3], edge_attr=[101184, 3], batch=[6345], ptr=[2])
# DataBatch(x=[773, 4], edge_index=[2, 11617], y=[1, 2], pos=[773, 3], edge_attr=[11617, 3], batch=[773], ptr=[2])
# DataBatch(x=[5892, 4], edge_index=[2, 93973], y=[1, 2], pos=[5892, 3], edge_attr=[93973, 3], batch=[5892], ptr=[2])
# DataBatch(x=[2708, 4], edge_index=[2, 42972], y=[1, 2], pos=[2708, 3], edge_attr=[42972, 3], batch=[2708], ptr=[2])
# DataBatch(x=[8424, 4], edge_index=[2, 134764], y=[1, 2], pos=[8424, 3], edge_attr=[134764, 3], batch=[8424], ptr=[2])
# DataBatch(x=[7501, 4], edge_index=[2, 119688], y=[1, 2], pos=[7501, 3], edge_attr=[119688, 3], batch=[7501], ptr=[2])
# DataBatch(x=[4910, 4], edge_index=[2, 77933], y=[1, 2], pos=[4910, 3], edge_attr=[77933, 3], batch=[4910], ptr=[2])
# DataBatch(x=[1596, 4], edge_index=[2, 24653], y=[1, 2], pos=[1596, 3], edge_attr=[24653, 3], batch=[1596], ptr=[2])
# DataBatch(x=[4815, 4], edge_index=[2, 76496], y=[1, 2], pos=[4815, 3], edge_attr=[76496, 3], batch=[4815], ptr=[2])
# DataBatch(x=[4378, 4], edge_index=[2, 69500], y=[1, 2], pos=[4378, 3], edge_attr=[69500, 3], batch=[4378], ptr=[2])
# DataBatch(x=[8298, 4], edge_index=[2, 132661], y=[1, 2], pos=[8298, 3], edge_attr=[132661, 3], batch=[8298], ptr=[2])
# DataBatch(x=[6570, 4], edge_index=[2, 104882], y=[1, 2], pos=[6570, 3], edge_attr=[104882, 3], batch=[6570], ptr=[2])
# DataBatch(x=[5136, 4], edge_index=[2, 81784], y=[1, 2], pos=[5136, 3], edge_attr=[81784, 3], batch=[5136], ptr=[2])
# DataBatch(x=[883, 4], edge_index=[2, 13301], y=[1, 2], pos=[883, 3], edge_attr=[13301, 3], batch=[883], ptr=[2])
# DataBatch(x=[7913, 4], edge_index=[2, 126334], y=[1, 2], pos=[7913, 3], edge_attr=[126334, 3], batch=[7913], ptr=[2])
# DataBatch(x=[3655, 4], edge_index=[2, 57929], y=[1, 2], pos=[3655, 3], edge_attr=[57929, 3], batch=[3655], ptr=[2])
# DataBatch(x=[5623, 4], edge_index=[2, 89526], y=[1, 2], pos=[5623, 3], edge_attr=[89526, 3], batch=[5623], ptr=[2])
# DataBatch(x=[2346, 4], edge_index=[2, 37148], y=[1, 2], pos=[2346, 3], edge_attr=[37148, 3], batch=[2346], ptr=[2])
# DataBatch(x=[2754, 4], edge_index=[2, 43543], y=[1, 2], pos=[2754, 3], edge_attr=[43543, 3], batch=[2754], ptr=[2])
# DataBatch(x=[8968, 4], edge_index=[2, 143488], y=[1, 2], pos=[8968, 3], edge_attr=[143488, 3], batch=[8968], ptr=[2])
# DataBatch(x=[5926, 4], edge_index=[2, 94436], y=[1, 2], pos=[5926, 3], edge_attr=[94436, 3], batch=[5926], ptr=[2])
# DataBatch(x=[2301, 4], edge_index=[2, 36261], y=[1, 2], pos=[2301, 3], edge_attr=[36261, 3], batch=[2301], ptr=[2])
# DataBatch(x=[5455, 4], edge_index=[2, 86877], y=[1, 2], pos=[5455, 3], edge_attr=[86877, 3], batch=[5455], ptr=[2])
# DataBatch(x=[4769, 4], edge_index=[2, 75752], y=[1, 2], pos=[4769, 3], edge_attr=[75752, 3], batch=[4769], ptr=[2])
# DataBatch(x=[2345, 4], edge_index=[2, 36800], y=[1, 2], pos=[2345, 3], edge_attr=[36800, 3], batch=[2345], ptr=[2])
# DataBatch(x=[6746, 4], edge_index=[2, 107790], y=[1, 2], pos=[6746, 3], edge_attr=[107790, 3], batch=[6746], ptr=[2])
# DataBatch(x=[5916, 4], edge_index=[2, 94368], y=[1, 2], pos=[5916, 3], edge_attr=[94368, 3], batch=[5916], ptr=[2])
# DataBatch(x=[5972, 4], edge_index=[2, 95197], y=[1, 2], pos=[5972, 3], edge_attr=[95197, 3], batch=[5972], ptr=[2])
# DataBatch(x=[6466, 4], edge_index=[2, 103225], y=[1, 2], pos=[6466, 3], edge_attr=[103225, 3], batch=[6466], ptr=[2])
# DataBatch(x=[5718, 4], edge_index=[2, 91236], y=[1, 2], pos=[5718, 3], edge_attr=[91236, 3], batch=[5718], ptr=[2])
# DataBatch(x=[4095, 4], edge_index=[2, 65207], y=[1, 2], pos=[4095, 3], edge_attr=[65207, 3], batch=[4095], ptr=[2])
# DataBatch(x=[3264, 4], edge_index=[2, 51819], y=[1, 2], pos=[3264, 3], edge_attr=[51819, 3], batch=[3264], ptr=[2])
# DataBatch(x=[8717, 4], edge_index=[2, 139431], y=[1, 2], pos=[8717, 3], edge_attr=[139431, 3], batch=[8717], ptr=[2])
# DataBatch(x=[7166, 4], edge_index=[2, 114476], y=[1, 2], pos=[7166, 3], edge_attr=[114476, 3], batch=[7166], ptr=[2])
# DataBatch(x=[4624, 4], edge_index=[2, 73500], y=[1, 2], pos=[4624, 3], edge_attr=[73500, 3], batch=[4624], ptr=[2])
# DataBatch(x=[5872, 4], edge_index=[2, 93702], y=[1, 2], pos=[5872, 3], edge_attr=[93702, 3], batch=[5872], ptr=[2])
# DataBatch(x=[2649, 4], edge_index=[2, 41888], y=[1, 2], pos=[2649, 3], edge_attr=[41888, 3], batch=[2649], ptr=[2])
# DataBatch(x=[8768, 4], edge_index=[2, 140274], y=[1, 2], pos=[8768, 3], edge_attr=[140274, 3], batch=[8768], ptr=[2])
# DataBatch(x=[8076, 4], edge_index=[2, 129197], y=[1, 2], pos=[8076, 3], edge_attr=[129197, 3], batch=[8076], ptr=[2])
# DataBatch(x=[5665, 4], edge_index=[2, 90305], y=[1, 2], pos=[5665, 3], edge_attr=[90305, 3], batch=[5665], ptr=[2])
# DataBatch(x=[6030, 4], edge_index=[2, 96225], y=[1, 2], pos=[6030, 3], edge_attr=[96225, 3], batch=[6030], ptr=[2])
# DataBatch(x=[6421, 4], edge_index=[2, 102371], y=[1, 2], pos=[6421, 3], edge_attr=[102371, 3], batch=[6421], ptr=[2])
# DataBatch(x=[4887, 4], edge_index=[2, 77735], y=[1, 2], pos=[4887, 3], edge_attr=[77735, 3], batch=[4887], ptr=[2])
# DataBatch(x=[7404, 4], edge_index=[2, 118224], y=[1, 2], pos=[7404, 3], edge_attr=[118224, 3], batch=[7404], ptr=[2])
# DataBatch(x=[6108, 4], edge_index=[2, 97441], y=[1, 2], pos=[6108, 3], edge_attr=[97441, 3], batch=[6108], ptr=[2])
# DataBatch(x=[6741, 4], edge_index=[2, 107455], y=[1, 2], pos=[6741, 3], edge_attr=[107455, 3], batch=[6741], ptr=[2])
# DataBatch(x=[5584, 4], edge_index=[2, 88974], y=[1, 2], pos=[5584, 3], edge_attr=[88974, 3], batch=[5584], ptr=[2])
# DataBatch(x=[3349, 4], edge_index=[2, 52879], y=[1, 2], pos=[3349, 3], edge_attr=[52879, 3], batch=[3349], ptr=[2])
# DataBatch(x=[8540, 4], edge_index=[2, 136460], y=[1, 2], pos=[8540, 3], edge_attr=[136460, 3], batch=[8540], ptr=[2])
# DataBatch(x=[1494, 4], edge_index=[2, 23409], y=[1, 2], pos=[1494, 3], edge_attr=[23409, 3], batch=[1494], ptr=[2])
# DataBatch(x=[3327, 4], edge_index=[2, 52882], y=[1, 2], pos=[3327, 3], edge_attr=[52882, 3], batch=[3327], ptr=[2])
# DataBatch(x=[5541, 4], edge_index=[2, 88432], y=[1, 2], pos=[5541, 3], edge_attr=[88432, 3], batch=[5541], ptr=[2])
# DataBatch(x=[2063, 4], edge_index=[2, 32500], y=[1, 2], pos=[2063, 3], edge_attr=[32500, 3], batch=[2063], ptr=[2])
# DataBatch(x=[1520, 4], edge_index=[2, 23795], y=[1, 2], pos=[1520, 3], edge_attr=[23795, 3], batch=[1520], ptr=[2])
# DataBatch(x=[7407, 4], edge_index=[2, 118332], y=[1, 2], pos=[7407, 3], edge_attr=[118332, 3], batch=[7407], ptr=[2])
# DataBatch(x=[2772, 4], edge_index=[2, 43335], y=[1, 2], pos=[2772, 3], edge_attr=[43335, 3], batch=[2772], ptr=[2])
# DataBatch(x=[5958, 4], edge_index=[2, 95081], y=[1, 2], pos=[5958, 3], edge_attr=[95081, 3], batch=[5958], ptr=[2])
# DataBatch(x=[4419, 4], edge_index=[2, 70346], y=[1, 2], pos=[4419, 3], edge_attr=[70346, 3], batch=[4419], ptr=[2])
# DataBatch(x=[1956, 4], edge_index=[2, 30813], y=[1, 2], pos=[1956, 3], edge_attr=[30813, 3], batch=[1956], ptr=[2])
# DataBatch(x=[7360, 4], edge_index=[2, 117636], y=[1, 2], pos=[7360, 3], edge_attr=[117636, 3], batch=[7360], ptr=[2])
# DataBatch(x=[1738, 4], edge_index=[2, 26899], y=[1, 2], pos=[1738, 3], edge_attr=[26899, 3], batch=[1738], ptr=[2])
# DataBatch(x=[2086, 4], edge_index=[2, 32953], y=[1, 2], pos=[2086, 3], edge_attr=[32953, 3], batch=[2086], ptr=[2])
# DataBatch(x=[4463, 4], edge_index=[2, 70895], y=[1, 2], pos=[4463, 3], edge_attr=[70895, 3], batch=[4463], ptr=[2])
# DataBatch(x=[7611, 4], edge_index=[2, 121593], y=[1, 2], pos=[7611, 3], edge_attr=[121593, 3], batch=[7611], ptr=[2])
# DataBatch(x=[5288, 4], edge_index=[2, 84139], y=[1, 2], pos=[5288, 3], edge_attr=[84139, 3], batch=[5288], ptr=[2])
# DataBatch(x=[1682, 4], edge_index=[2, 26400], y=[1, 2], pos=[1682, 3], edge_attr=[26400, 3], batch=[1682], ptr=[2])
# DataBatch(x=[713, 4], edge_index=[2, 10909], y=[1, 2], pos=[713, 3], edge_attr=[10909, 3], batch=[713], ptr=[2])
# DataBatch(x=[6235, 4], edge_index=[2, 99674], y=[1, 2], pos=[6235, 3], edge_attr=[99674, 3], batch=[6235], ptr=[2])
# DataBatch(x=[4134, 4], edge_index=[2, 65767], y=[1, 2], pos=[4134, 3], edge_attr=[65767, 3], batch=[4134], ptr=[2])
# DataBatch(x=[2397, 4], edge_index=[2, 37592], y=[1, 2], pos=[2397, 3], edge_attr=[37592, 3], batch=[2397], ptr=[2])
# DataBatch(x=[2230, 4], edge_index=[2, 34897], y=[1, 2], pos=[2230, 3], edge_attr=[34897, 3], batch=[2230], ptr=[2])
# DataBatch(x=[2408, 4], edge_index=[2, 38099], y=[1, 2], pos=[2408, 3], edge_attr=[38099, 3], batch=[2408], ptr=[2])
# DataBatch(x=[6658, 4], edge_index=[2, 106324], y=[1, 2], pos=[6658, 3], edge_attr=[106324, 3], batch=[6658], ptr=[2])
# DataBatch(x=[4189, 4], edge_index=[2, 66406], y=[1, 2], pos=[4189, 3], edge_attr=[66406, 3], batch=[4189], ptr=[2])
# DataBatch(x=[7078, 4], edge_index=[2, 113129], y=[1, 2], pos=[7078, 3], edge_attr=[113129, 3], batch=[7078], ptr=[2])
# DataBatch(x=[6267, 4], edge_index=[2, 99972], y=[1, 2], pos=[6267, 3], edge_attr=[99972, 3], batch=[6267], ptr=[2])
# DataBatch(x=[6435, 4], edge_index=[2, 102646], y=[1, 2], pos=[6435, 3], edge_attr=[102646, 3], batch=[6435], ptr=[2])
# DataBatch(x=[5617, 4], edge_index=[2, 89465], y=[1, 2], pos=[5617, 3], edge_attr=[89465, 3], batch=[5617], ptr=[2])
# DataBatch(x=[4203, 4], edge_index=[2, 66524], y=[1, 2], pos=[4203, 3], edge_attr=[66524, 3], batch=[4203], ptr=[2])
# DataBatch(x=[1414, 4], edge_index=[2, 22123], y=[1, 2], pos=[1414, 3], edge_attr=[22123, 3], batch=[1414], ptr=[2])
# DataBatch(x=[1492, 4], edge_index=[2, 23348], y=[1, 2], pos=[1492, 3], edge_attr=[23348, 3], batch=[1492], ptr=[2])
# DataBatch(x=[2870, 4], edge_index=[2, 45498], y=[1, 2], pos=[2870, 3], edge_attr=[45498, 3], batch=[2870], ptr=[2])
# DataBatch(x=[2947, 4], edge_index=[2, 46297], y=[1, 2], pos=[2947, 3], edge_attr=[46297, 3], batch=[2947], ptr=[2])
# DataBatch(x=[4246, 4], edge_index=[2, 67573], y=[1, 2], pos=[4246, 3], edge_attr=[67573, 3], batch=[4246], ptr=[2])
# DataBatch(x=[6643, 4], edge_index=[2, 106194], y=[1, 2], pos=[6643, 3], edge_attr=[106194, 3], batch=[6643], ptr=[2])
# DataBatch(x=[4159, 4], edge_index=[2, 65967], y=[1, 2], pos=[4159, 3], edge_attr=[65967, 3], batch=[4159], ptr=[2])
# DataBatch(x=[7762, 4], edge_index=[2, 124078], y=[1, 2], pos=[7762, 3], edge_attr=[124078, 3], batch=[7762], ptr=[2])
# DataBatch(x=[7884, 4], edge_index=[2, 126150], y=[1, 2], pos=[7884, 3], edge_attr=[126150, 3], batch=[7884], ptr=[2])
# DataBatch(x=[4020, 4], edge_index=[2, 63837], y=[1, 2], pos=[4020, 3], edge_attr=[63837, 3], batch=[4020], ptr=[2])
# DataBatch(x=[5742, 4], edge_index=[2, 91457], y=[1, 2], pos=[5742, 3], edge_attr=[91457, 3], batch=[5742], ptr=[2])
# DataBatch(x=[6875, 4], edge_index=[2, 109807], y=[1, 2], pos=[6875, 3], edge_attr=[109807, 3], batch=[6875], ptr=[2])
# DataBatch(x=[2319, 4], edge_index=[2, 36633], y=[1, 2], pos=[2319, 3], edge_attr=[36633, 3], batch=[2319], ptr=[2])
# DataBatch(x=[2528, 4], edge_index=[2, 39968], y=[1, 2], pos=[2528, 3], edge_attr=[39968, 3], batch=[2528], ptr=[2])
# DataBatch(x=[3386, 4], edge_index=[2, 53694], y=[1, 2], pos=[3386, 3], edge_attr=[53694, 3], batch=[3386], ptr=[2])
# DataBatch(x=[5823, 4], edge_index=[2, 92868], y=[1, 2], pos=[5823, 3], edge_attr=[92868, 3], batch=[5823], ptr=[2])
# DataBatch(x=[6813, 4], edge_index=[2, 108831], y=[1, 2], pos=[6813, 3], edge_attr=[108831, 3], batch=[6813], ptr=[2])
# DataBatch(x=[6822, 4], edge_index=[2, 108958], y=[1, 2], pos=[6822, 3], edge_attr=[108958, 3], batch=[6822], ptr=[2])
# DataBatch(x=[6442, 4], edge_index=[2, 102810], y=[1, 2], pos=[6442, 3], edge_attr=[102810, 3], batch=[6442], ptr=[2])
# DataBatch(x=[5840, 4], edge_index=[2, 93149], y=[1, 2], pos=[5840, 3], edge_attr=[93149, 3], batch=[5840], ptr=[2])
# DataBatch(x=[6804, 4], edge_index=[2, 108816], y=[1, 2], pos=[6804, 3], edge_attr=[108816, 3], batch=[6804], ptr=[2])
# DataBatch(x=[3567, 4], edge_index=[2, 56551], y=[1, 2], pos=[3567, 3], edge_attr=[56551, 3], batch=[3567], ptr=[2])
# DataBatch(x=[6006, 4], edge_index=[2, 96026], y=[1, 2], pos=[6006, 3], edge_attr=[96026, 3], batch=[6006], ptr=[2])
# DataBatch(x=[6162, 4], edge_index=[2, 98333], y=[1, 2], pos=[6162, 3], edge_attr=[98333, 3], batch=[6162], ptr=[2])
# DataBatch(x=[2348, 4], edge_index=[2, 37101], y=[1, 2], pos=[2348, 3], edge_attr=[37101, 3], batch=[2348], ptr=[2])
# DataBatch(x=[5726, 4], edge_index=[2, 91376], y=[1, 2], pos=[5726, 3], edge_attr=[91376, 3], batch=[5726], ptr=[2])
# DataBatch(x=[7392, 4], edge_index=[2, 118016], y=[1, 2], pos=[7392, 3], edge_attr=[118016, 3], batch=[7392], ptr=[2])
# DataBatch(x=[6363, 4], edge_index=[2, 101589], y=[1, 2], pos=[6363, 3], edge_attr=[101589, 3], batch=[6363], ptr=[2])
# DataBatch(x=[6085, 4], edge_index=[2, 96912], y=[1, 2], pos=[6085, 3], edge_attr=[96912, 3], batch=[6085], ptr=[2])
# DataBatch(x=[1243, 4], edge_index=[2, 19299], y=[1, 2], pos=[1243, 3], edge_attr=[19299, 3], batch=[1243], ptr=[2])
# DataBatch(x=[6765, 4], edge_index=[2, 107893], y=[1, 2], pos=[6765, 3], edge_attr=[107893, 3], batch=[6765], ptr=[2])
# DataBatch(x=[2382, 4], edge_index=[2, 37474], y=[1, 2], pos=[2382, 3], edge_attr=[37474, 3], batch=[2382], ptr=[2])
# DataBatch(x=[5944, 4], edge_index=[2, 94933], y=[1, 2], pos=[5944, 3], edge_attr=[94933, 3], batch=[5944], ptr=[2])
# DataBatch(x=[841, 4], edge_index=[2, 12944], y=[1, 2], pos=[841, 3], edge_attr=[12944, 3], batch=[841], ptr=[2])
# DataBatch(x=[6518, 4], edge_index=[2, 104046], y=[1, 2], pos=[6518, 3], edge_attr=[104046, 3], batch=[6518], ptr=[2])
# DataBatch(x=[6537, 4], edge_index=[2, 104400], y=[1, 2], pos=[6537, 3], edge_attr=[104400, 3], batch=[6537], ptr=[2])
# DataBatch(x=[6493, 4], edge_index=[2, 103691], y=[1, 2], pos=[6493, 3], edge_attr=[103691, 3], batch=[6493], ptr=[2])
# DataBatch(x=[1390, 4], edge_index=[2, 21628], y=[1, 2], pos=[1390, 3], edge_attr=[21628, 3], batch=[1390], ptr=[2])
# DataBatch(x=[9221, 4], edge_index=[2, 147534], y=[1, 2], pos=[9221, 3], edge_attr=[147534, 3], batch=[9221], ptr=[2])
# DataBatch(x=[5875, 4], edge_index=[2, 93788], y=[1, 2], pos=[5875, 3], edge_attr=[93788, 3], batch=[5875], ptr=[2])
# DataBatch(x=[5839, 4], edge_index=[2, 93224], y=[1, 2], pos=[5839, 3], edge_attr=[93224, 3], batch=[5839], ptr=[2])
# DataBatch(x=[5395, 4], edge_index=[2, 86048], y=[1, 2], pos=[5395, 3], edge_attr=[86048, 3], batch=[5395], ptr=[2])
# DataBatch(x=[1437, 4], edge_index=[2, 22491], y=[1, 2], pos=[1437, 3], edge_attr=[22491, 3], batch=[1437], ptr=[2])
# DataBatch(x=[5621, 4], edge_index=[2, 89512], y=[1, 2], pos=[5621, 3], edge_attr=[89512, 3], batch=[5621], ptr=[2])
# DataBatch(x=[6465, 4], edge_index=[2, 103145], y=[1, 2], pos=[6465, 3], edge_attr=[103145, 3], batch=[6465], ptr=[2])
# DataBatch(x=[2129, 4], edge_index=[2, 33587], y=[1, 2], pos=[2129, 3], edge_attr=[33587, 3], batch=[2129], ptr=[2])
# DataBatch(x=[7588, 4], edge_index=[2, 121278], y=[1, 2], pos=[7588, 3], edge_attr=[121278, 3], batch=[7588], ptr=[2])
# DataBatch(x=[7705, 4], edge_index=[2, 123209], y=[1, 2], pos=[7705, 3], edge_attr=[123209, 3], batch=[7705], ptr=[2])
# DataBatch(x=[8477, 4], edge_index=[2, 135626], y=[1, 2], pos=[8477, 3], edge_attr=[135626, 3], batch=[8477], ptr=[2])
# DataBatch(x=[5026, 4], edge_index=[2, 80101], y=[1, 2], pos=[5026, 3], edge_attr=[80101, 3], batch=[5026], ptr=[2])
# DataBatch(x=[7040, 4], edge_index=[2, 112385], y=[1, 2], pos=[7040, 3], edge_attr=[112385, 3], batch=[7040], ptr=[2])
# DataBatch(x=[2880, 4], edge_index=[2, 45605], y=[1, 2], pos=[2880, 3], edge_attr=[45605, 3], batch=[2880], ptr=[2])
# DataBatch(x=[6905, 4], edge_index=[2, 110402], y=[1, 2], pos=[6905, 3], edge_attr=[110402, 3], batch=[6905], ptr=[2])
# DataBatch(x=[6112, 4], edge_index=[2, 97465], y=[1, 2], pos=[6112, 3], edge_attr=[97465, 3], batch=[6112], ptr=[2])
# DataBatch(x=[5623, 4], edge_index=[2, 89689], y=[1, 2], pos=[5623, 3], edge_attr=[89689, 3], batch=[5623], ptr=[2])
# DataBatch(x=[4738, 4], edge_index=[2, 75423], y=[1, 2], pos=[4738, 3], edge_attr=[75423, 3], batch=[4738], ptr=[2])
# DataBatch(x=[6420, 4], edge_index=[2, 102475], y=[1, 2], pos=[6420, 3], edge_attr=[102475, 3], batch=[6420], ptr=[2])
